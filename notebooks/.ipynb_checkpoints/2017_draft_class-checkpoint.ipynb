# %%
pip install basketball_reference_scraper
# Out:
# ...
#
# ...

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2017)
draft['YEAR'] =  2017
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM               PLAYER         COLLEGE YEARS TOTALS_G TOTALS_MP  \
# 0     1  PHI       Markelle Fultz      Washington     7      234      5939
# 1     2  LAL           Lonzo Ball            UCLA     5      252      8187
# 2     3  BOS         Jayson Tatum            Duke     7      513     17561
# 3     4  PHO         Josh Jackson          Kansas     5      291      6718
# 4     5  SAC         De'Aaron Fox        Kentucky     7      469     15420
# 5     6  ORL       Jonathan Isaac   Florida State     5      205      4550
# 6     7  MIN      Lauri Markkanen         Arizona     7      403     12482
# 7     8  NYK      Frank Ntilikina             NaN     7      321      5454
# ...

# %%
atl = get_roster_stats('ATL', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
bos = get_roster_stats('BOS', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
brk = get_roster_stats('BRK', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
cho = get_roster_stats('CHO', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
chi = get_roster_stats('CHI', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cle = get_roster_stats('CLE', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
dal = get_roster_stats('DAL', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
den = get_roster_stats('DEN', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
det = get_roster_stats('DET', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
gsw = get_roster_stats('GSW', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
hou = get_roster_stats('HOU', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
ind = get_roster_stats('IND', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
lac = get_roster_stats('LAC', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
lal = get_roster_stats('LAL', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mem = get_roster_stats('MEM', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mia = get_roster_stats('MIA', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mil = get_roster_stats('MIL', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
minn = get_roster_stats('MIN', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
nop = get_roster_stats('NOP', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nyk = get_roster_stats('NYK', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
okc = get_roster_stats('OKC', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
orl = get_roster_stats('ORL', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
phi = get_roster_stats('PHI', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
pho = get_roster_stats('PHO', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
por = get_roster_stats('POR', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sac = get_roster_stats('SAC', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
sas = get_roster_stats('SAS', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
tor = get_roster_stats('TOR', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
uta = get_roster_stats('UTA', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
was = get_roster_stats('WAS', 2018, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM','YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#            PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0  Markelle Fultz    1  PHI  2017  14.0  18.1  3.2   7.9  0.7  1.5  0.8  2.3
# 1      Lonzo Ball    2  LAL  2017  52.0  34.2  3.9  10.8  0.6  1.4  1.3  5.6
# 2    Jayson Tatum    3  BOS  2017  80.0  30.5  5.0  10.4  2.7  3.2  0.6  4.4
# 3    Josh Jackson    4  PHO  2017  77.0  25.4  5.1  12.1  2.3  3.6  1.2  3.3
# 4    De'Aaron Fox    5  SAC  2017  73.0  27.8  4.5  10.9  1.9  2.7  0.5  2.3
#
#    AST  STL  BLK  TOV   PF   PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  3.8  0.9  0.3  1.2  1.6   7.1         8.5         -1.1           1.3
# 1  7.2  1.7  0.8  2.6  2.3  10.2        11.4          1.1           6.3
# 2  1.6  1.0  0.7  1.4  2.1  13.9        55.9          3.6          24.6
# 3  1.5  1.0  0.5  1.9  2.8  13.1        -1.7         -3.8          -3.1
# 4  4.4  1.0  0.3  2.4  2.2  11.6        29.6          0.9          11.4

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         60 non-null     object
#  1   PICK           60 non-null     object
#  2   TEAM           60 non-null     object
#  3   YEAR           60 non-null     int64
#  4   G              48 non-null     float64
#  5   MP             48 non-null     float64
#  6   FG             48 non-null     float64
#  7   FGA            48 non-null     float64
#  8   FT             48 non-null     float64
#  9   FTA            48 non-null     float64
#  10  ORB            48 non-null     float64
#  11  DRB            48 non-null     float64
#  12  AST            48 non-null     float64
#  13  STL            48 non-null     float64
#  14  BLK            48 non-null     float64
#  15  TOV            48 non-null     float64
#  16  PF             48 non-null     float64
# ...

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
#            PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0  Markelle Fultz    1  PHI  2017  14.0  18.1  3.2   7.9  0.7  1.5  0.8  2.3
# 1      Lonzo Ball    2  LAL  2017  52.0  34.2  3.9  10.8  0.6  1.4  1.3  5.6
# 2    Jayson Tatum    3  BOS  2017  80.0  30.5  5.0  10.4  2.7  3.2  0.6  4.4
# 3    Josh Jackson    4  PHO  2017  77.0  25.4  5.1  12.1  2.3  3.6  1.2  3.3
# 4    De'Aaron Fox    5  SAC  2017  73.0  27.8  4.5  10.9  1.9  2.7  0.5  2.3
#
#    AST  STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP  \
# 0  3.8  0.9  0.3  1.2  1.6   7.1          8.5          -1.1            1.3
# 1  7.2  1.7  0.8  2.6  2.3  10.2         11.4           1.1            6.3
# 2  1.6  1.0  0.7  1.4  2.1  13.9         55.9           3.6           24.6
# 3  1.5  1.0  0.5  1.9  2.8  13.1         -1.7          -3.8           -3.1
# 4  4.4  1.0  0.3  2.4  2.2  11.6         29.6           0.9           11.4
#
#     PER
# 0  12.0
# 1  11.6
# 2  13.6
# 3  10.6
# ...

# %%
rookie_merge.to_csv('2017_draft_class.csv', index=False)
