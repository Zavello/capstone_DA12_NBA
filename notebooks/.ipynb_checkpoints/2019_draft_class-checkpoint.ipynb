# %%
pip install basketball_reference_scraper
# Out:
# Requirement already satisfied: basketball_reference_scraper in c:\users\zecha\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (4.12.3)
# Requirement already satisfied: bs4 in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (0.0.2)
# Requirement already satisfied: lxml in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (5.2.1)
# Requirement already satisfied: numpy in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.26.4)
# Requirement already satisfied: pandas in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.2.2)
# Requirement already satisfied: python-dateutil in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.9.0.post0)
# Requirement already satisfied: pytz in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2024.1)
# Requirement already satisfied: requests in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.32.2)
# Requirement already satisfied: six in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.16.0)
# Requirement already satisfied: soupsieve in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.5)
# Requirement already satisfied: Unidecode in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.2.0)
# Requirement already satisfied: selenium in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (4.24.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zecha\anaconda3\lib\site-packages (from pandas->basketball_reference_scraper) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2024.7.4)
# Requirement already satisfied: trio~=0.17 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (0.11.1)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (2.4.0)
# Requirement already satisfied: outcome in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\zecha\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium->basketball_reference_scraper) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\zecha\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium->basketball_reference_scraper) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\zecha\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->basketball_reference_scraper) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\zecha\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->basketball_reference_scraper) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2019)
draft['YEAR'] =  2019
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM                    PLAYER                COLLEGE YEARS TOTALS_G  \
# 0     1  NOP           Zion Williamson                   Duke     4      184
# 1     2  MEM                 Ja Morant           Murray State     5      257
# 2     3  NYK                RJ Barrett                   Duke     5      329
# 3     4  LAL           De'Andre Hunter               Virginia     5      263
# 4     5  CLE            Darius Garland             Vanderbilt     5      307
# 5     6  PHO            Jarrett Culver             Texas Tech     4      144
# 6     7  CHI                Coby White                    UNC     5      348
# 7     8  ATL              Jaxson Hayes                  Texas     5      311
# 8     9  WAS             Rui Hachimura                Gonzaga     5      278
# 9    10  ATL               Cam Reddish                   Duke     5      221
# 10   11  MIN           Cameron Johnson                    UNC     5      283
# 11   12  CHO           P.J. Washington               Kentucky     5      333
# 12   13  MIA               Tyler Herro               Kentucky     5      284
# 13   14  BOS            Romeo Langford                Indiana     4      141
# 14   15  DET           Sekou Doumbouya                    NaN     3       96
# 15   16  ORL               Chuma Okeke                 Auburn     4      189
# 16   17  BRK  Nickeil Alexander-Walker          Virginia Tech     5      299
# 17   18  IND              Goga Bitadze                    NaN     5      249
# 18   19  SAS              Luka Šamanić                    NaN     4       86
# 19   20  BOS          Matisse Thybulle             Washington     5      332
# 20   21  OKC            Brandon Clarke                Gonzaga     5      243
# 21   22  BOS            Grant Williams              Tennessee     5      364
# 22   23  UTA             Darius Bazley                    NaN     5      237
# 23   24  PHI                 Ty Jerome               Virginia     5      159
# 24   25  POR             Nassir Little                    UNC     5      237
# 25   26  CLE             Dylan Windler                Belmont     4      101
# 26   27  BRK         Mfiondu Kabengele          Florida State     3       55
# 27   28  GSW              Jordan Poole               Michigan     5      344
# 28   29  SAS            Keldon Johnson               Kentucky     5      293
# 29   30  MIL          Kevin Porter Jr.                    USC     4      196
# 32   31  BRK               Nic Claxton                Georgia     5      241
# 33   32  PHO                 KZ Okpala               Stanford     4       98
# 34   33  PHI            Carsen Edwards                 Purdue     3       72
# 35   34  PHI            Bruno Fernando               Maryland     5      203
# 36   35  ATL              Didi Louzada                    NaN     2       12
# 37   36  CHO               Cody Martin                 Nevada     5      206
# 38   37  DAL         Deividas Sirvydis                    NaN     2       23
# 39   38  CHI            Daniel Gafford               Arkansas     5      321
# 40   39  NOP            Alen Smailagić                    NaN     2       29
# 41   40  SAC              Justin James                Wyoming     2       72
# 42   41  GSW             Eric Paschall              Villanova     3      158
# 43   42  PHI         Admiral Schofield              Tennessee     4      131
# 44   43  MIN             Jaylen Nowell             Washington     5      197
# 45   44  MIA                   Bol Bol                 Oregon     5      166
# 46   45  DET               Isaiah Roby               Nebraska     4      151
# 47   46  ORL       Talen Horton-Tucker             Iowa State     5      247
# 48   47  SAC          Ignas Brazdeikis               Michigan     3       64
# 49   48  LAC              Terance Mann          Florida State     5      345
# 50   49  SAS    Quinndary Weatherspoon      Mississippi State     3       42
# 51   50  IND          Jarrell Brantley  College of Charleston     3       41
# 52   51  BOS            Tremont Waters                    LSU     3       40
# 53   52  CHO           Jalen McDaniels        San Diego State     5      248
# 54   53  UTA     Justin Wright-Foreman                Hofstra     1        4
# 55   54  PHI             Marial Shayok             Iowa State     1        4
# 56   55  NYK                  Kyle Guy               Virginia     3       53
# 57   56  LAC              Jaylen Hands                   UCLA   NaN      NaN
# 58   57  NOP               Jordan Bone              Tennessee     2       24
# 59   58  GSW                  Miye Oni                   Yale     3       80
# 60   59  TOR           Dewan Hernandez             Miami (FL)     1        6
# 61   60  SAC          Vanja Marinković                    NaN   NaN      NaN
#
#    TOTALS_MP TOTALS_PTS TOTALS_TRB TOTALS_AST SHOOTING_FG% SHOOTING_3P%  \
# 0       5857       4542       1199        761         .592         .341
# 1       8282       5783       1243       1903         .472         .318
# 2      10945       6070       1784        962         .435         .346
# 3       8080       3751       1078        405         .447         .363
# 4      10392       5660        801       2052         .448         .384
# 5       2480        934        402        173         .401         .276
# 6      10116       4896       1266       1288         .427         .369
# 7       4929       2111       1174        201         .636         .268
# 8       7476       3543       1343        356         .493         .371
# 9       5287       2046        612        275         .398         .324
# 10      7220       3325       1095        470         .447         .392
# 11     10082       4285       1840        747         .447         .354
# 12      9038       5147       1403       1036         .440         .385
# 13      2268        650        298         97         .430         .288
# 14      1639        542        267         66         .388         .256
# 15      3832       1189        704        276         .383         .318
# 16      5869       2485        683        659         .407         .354
# 17      3175       1230        856        233         .515         .245
# 18       921        384        210         55         .411         .247
# 19      6957       1586        658        360         .435         .338
# 20      5185       2602       1357        343         .603         .286
# 21      8231       2558       1311        515         .453         .377
# 22      5536       2113       1244        282         .414         .309
# 23      2748       1108        294        411         .421         .352
# 24      3735       1313        688        170         .452         .330
# 25      1090        319        212         78         .425         .347
# 26       380        143         81         19         .383         .301
# 27      9349       5551        907       1249         .419         .336
# 28      8762       4782       1621        672         .465         .358
# 29      5928       3008        842        987         .431         .357
# 32      6142       2490       1882        378         .661         .158
# 33       965        222        148         47         .409         .286
# 34       706        267         79         52         .364         .297
# 35      2179        814        661        143         .544         .122
# 36       185         43         20          8         .326         .355
# 37      4505       1235        737        475         .442         .317
# 38       160         44         35          6         .300         .314
# 39      6263       2796       1739        317         .711         .000
# 40       223         87         43         17         .463         .304
# 41       542        228         62         40         .446         .343
# 42      3086       1552        509        214         .494         .326
# 43      1372        426        215         78         .417         .326
# 44      3351       1748        425        362         .446         .317
# 45      2302        999        605        104         .550         .327
# 46      2858       1159        667        216         .485         .351
# 47      5218       2430        700        769         .423         .293
# 48       838        318        122         58         .416         .315
# 49      7687       2814       1252        669         .503         .373
# 50       272         88         32         24         .452         .188
# 51       273        110         53         29         .457         .380
# 52       407        149         37         85         .354         .296
# 53      4543       1699        829        291         .449         .322
# 54        45         19          5          7         .350         .200
# 55        28         11          7          1         .250         .333
# 56       431        165         53         50         .361         .303
# 57       NaN        NaN        NaN        NaN          NaN          NaN
# 58       249         68         28         26         .378         .286
# 59       672        145        108         37         .350         .330
# 60        28         14         14          3         .357         .500
# 61       NaN        NaN        NaN        NaN          NaN          NaN
#
#    SHOOTING_FT% PER_GAME_MP PER_GAME_PTS PER_GAME_TRB PER_GAME_AST  \
# 0          .695        31.8         24.7          6.5          4.1
# 1          .755        32.2         22.5          4.8          7.4
# 2          .710        33.3         18.4          5.4          2.9
# 3          .811        30.7         14.3          4.1          1.5
# 4          .864        33.9         18.4          2.6          6.7
# 5          .509        17.2          6.5          2.8          1.2
# 6          .848        29.1         14.1          3.6          3.7
# 7          .707        15.8          6.8          3.8          0.6
# 8          .763        26.9         12.7          4.8          1.3
# 9          .833        23.9          9.3          2.8          1.2
# 10         .830        25.5         11.7          3.9          1.7
# 11         .705        30.3         12.9          5.5          2.2
# 12         .872        31.8         18.1          4.9          3.6
# 13         .659        16.1          4.6          2.1          0.7
# 14         .693        17.1          5.6          2.8          0.7
# 15         .789        20.3          6.3          3.7          1.5
# 16         .730        19.6          8.3          2.3          2.2
# 17         .672        12.8          4.9          3.4          0.9
# 18         .706        10.7          4.5          2.4          0.6
# 19         .679        21.0          4.8          2.0          1.1
# 20         .697        21.3         10.7          5.6          1.4
# 21         .768        22.6          7.0          3.6          1.4
# 22         .677        23.4          8.9          5.2          1.2
# 23         .826        17.3          7.0          1.8          2.6
# 24         .735        15.8          5.5          2.9          0.7
# 25         .800        10.8          3.2          2.1          0.8
# 26         .852         6.9          2.6          1.5          0.3
# 27         .878        27.2         16.1          2.6          3.6
# 28         .760        29.9         16.3          5.5          2.3
# 29         .725        30.2         15.3          4.3          5.0
# 32         .544        25.5         10.3          7.8          1.6
# 33         .667         9.8          2.3          1.5          0.5
# 34         .758         9.8          3.7          1.1          0.7
# 35         .650        10.7          4.0          3.3          0.7
# 36        1.000        15.4          3.6          1.7          0.7
# 37         .651        21.9          6.0          3.6          2.3
# 38         .500         7.0          1.9          1.5          0.3
# 39         .668        19.5          8.7          5.4          1.0
# 40         .720         7.7          3.0          1.5          0.6
# 41         .544         7.5          3.2          0.9          0.6
# 42         .758        19.5          9.8          3.2          1.4
# 43         .782        10.5          3.3          1.6          0.6
# 44         .798        17.0          8.9          2.2          1.8
# 45         .745        13.9          6.0          3.6          0.6
# 46         .675        18.9          7.7          4.4          1.4
# 47         .778        21.1          9.8          2.8          3.1
# 48         .686        13.1          5.0          1.9          0.9
# 49         .793        22.3          8.2          3.6          1.9
# 50         .826         6.5          2.1          0.8          0.6
# 51         .833         6.7          2.7          1.3          0.7
# 52         .960        10.2          3.7          0.9          2.1
# 53         .777        18.3          6.9          3.3          1.2
# 54         .750        11.3          4.8          1.3          1.8
# 55         .750         7.0          2.8          1.8          0.3
# 56         .750         8.1          3.1          1.0          0.9
# 57          NaN         NaN          NaN          NaN          NaN
# 58          NaN        10.4          2.8          1.2          1.1
# 59         .750         8.4          1.8          1.4          0.5
# 60         .600         4.7          2.3          2.3          0.5
# 61          NaN         NaN          NaN          NaN          NaN
#
#    ADVANCED_WS ADVANCED_WS/48 ADVANCED_BPM ADVANCED_VORP  YEAR
# 0         21.7           .178          4.6           9.8  2019
# 1         20.5           .119          2.8          10.1  2019
# 2         10.9           .048         -2.1          -0.4  2019
# 3          7.6           .045         -3.2          -2.5  2019
# 4         16.5           .076         -0.3           4.3  2019
# 5         -0.1          -.001         -4.5          -1.6  2019
# 6         13.5           .064         -1.7           0.8  2019
# 7         16.4           .160         -0.4           2.0  2019
# 8         11.3           .072         -2.2          -0.4  2019
# 9          2.6           .023         -3.2          -1.6  2019
# 10        17.7           .118          1.2           5.9  2019
# 11        12.5           .059         -1.2           1.9  2019
# 12        12.5           .067         -0.1           4.5  2019
# 13         2.0           .043         -3.4          -0.8  2019
# 14        -0.4          -.013         -6.5          -1.8  2019
# 15         4.4           .055         -1.1           0.9  2019
# 16         6.0           .049         -1.5           0.8  2019
# 17         9.1           .137          0.0           1.6  2019
# 18         0.0           .001         -5.6          -0.8  2019
# 19        13.2           .091          0.7           4.7  2019
# 20        20.2           .187          2.8           6.2  2019
# 21        14.8           .086         -1.9           0.3  2019
# 22         3.1           .027         -2.4          -0.6  2019
# 23         3.9           .069         -1.6           0.3  2019
# 24         4.7           .061         -2.6          -0.5  2019
# 25         1.6           .072         -1.4           0.2  2019
# 26         0.4           .055         -3.6          -0.2  2019
# 27         9.3           .048         -2.2          -0.4  2019
# 28        13.5           .074         -1.3           1.6  2019
# 29         4.0           .032         -1.6           0.7  2019
# 32        21.8           .170          1.6           5.6  2019
# 33         1.0           .050         -4.7          -0.7  2019
# 34         0.3           .019         -5.1          -0.5  2019
# 35         3.6           .078         -3.1          -0.6  2019
# 36        -0.1          -.034         -8.1          -0.3  2019
# 37         5.9           .063         -1.7           0.3  2019
# 38        -0.1          -.032         -5.9          -0.2  2019
# 39        25.2           .193          1.5           5.6  2019
# 40         0.3           .056         -3.3          -0.1  2019
# 41         0.3           .024         -3.1          -0.2  2019
# 42         5.0           .078         -2.2          -0.1  2019
# 43         1.2           .043         -4.6          -0.9  2019
# 44         4.9           .070         -1.9           0.1  2019
# 45         4.1           .086         -0.6           0.8  2019
# 46         4.0           .068         -2.3          -0.2  2019
# 47         4.9           .045         -1.9           0.1  2019
# 48         0.4           .024         -4.9          -0.6  2019
# 49        18.5           .115         -0.7           2.5  2019
# 50         0.2           .030         -5.5          -0.2  2019
# 51         0.6           .108          0.0           0.1  2019
# 52         0.1           .012         -3.0          -0.1  2019
# 53         5.3           .056         -3.3          -1.5  2019
# 54         0.0          -.008         -9.0          -0.1  2019
# 55        -0.1          -.130        -13.0          -0.1  2019
# 56         0.1           .006         -4.9          -0.3  2019
# 57         NaN            NaN          NaN           NaN  2019
# 58         0.1           .010         -5.9          -0.2  2019
# 59         1.0           .070         -2.5          -0.1  2019
# 60         0.0           .043         -9.6          -0.1  2019
# 61         NaN            NaN          NaN           NaN  2019

# %%
atl = get_roster_stats('ATL', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
bos = get_roster_stats('BOS', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
brk = get_roster_stats('BRK', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
cho = get_roster_stats('CHO', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
chi = get_roster_stats('CHI', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
cle = get_roster_stats('CLE', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
dal = get_roster_stats('DAL', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
den = get_roster_stats('DEN', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
det = get_roster_stats('DET', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
gsw = get_roster_stats('GSW', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
hou = get_roster_stats('HOU', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
ind = get_roster_stats('IND', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
lac = get_roster_stats('LAC', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
lal = get_roster_stats('LAL', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mem = get_roster_stats('MEM', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mia = get_roster_stats('MIA', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mil = get_roster_stats('MIL', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
minn = get_roster_stats('MIN', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
nop = get_roster_stats('NOP', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
nyk = get_roster_stats('NYK', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
okc = get_roster_stats('OKC', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
orl = get_roster_stats('ORL', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
phi = get_roster_stats('PHI', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
pho = get_roster_stats('PHO', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
por = get_roster_stats('POR', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sac = get_roster_stats('SAC', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sas = get_roster_stats('SAS', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
tor = get_roster_stats('TOR', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
uta = get_roster_stats('UTA', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
was = get_roster_stats('WAS', 2020, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
# atl = get_roster_stats('ATL', 2020, data_format='PER_GAME', playoffs=False)
# bos = get_roster_stats('BOS', 2020, data_format='PER_GAME', playoffs=False)
# brk = get_roster_stats('BRK', 2020, data_format='PER_GAME', playoffs=False)
# cho = get_roster_stats('CHO', 2020, data_format='PER_GAME', playoffs=False)
# chi = get_roster_stats('CHI', 2020, data_format='PER_GAME', playoffs=False)
# cle = get_roster_stats('CLE', 2020, data_format='PER_GAME', playoffs=False)
# dal = get_roster_stats('DAL', 2020, data_format='PER_GAME', playoffs=False)
# den = get_roster_stats('DEN', 2020, data_format='PER_GAME', playoffs=False)
# det = get_roster_stats('DET', 2020, data_format='PER_GAME', playoffs=False)
# gsw = get_roster_stats('GSW', 2020, data_format='PER_GAME', playoffs=False)
# hou = get_roster_stats('HOU', 2020, data_format='PER_GAME', playoffs=False)
# ind = get_roster_stats('IND', 2020, data_format='PER_GAME', playoffs=False)
# lac = get_roster_stats('LAC', 2020, data_format='PER_GAME', playoffs=False)
# lal = get_roster_stats('LAL', 2020, data_format='PER_GAME', playoffs=False)
# mem = get_roster_stats('MEM', 2020, data_format='PER_GAME', playoffs=False)
# mia = get_roster_stats('MIA', 2020, data_format='PER_GAME', playoffs=False)
# mil = get_roster_stats('MIL', 2020, data_format='PER_GAME', playoffs=False)
# minn = get_roster_stats('MIN', 2020, data_format='PER_GAME', playoffs=False)
# nop = get_roster_stats('NOP', 2020, data_format='PER_GAME', playoffs=False)
# nyk = get_roster_stats('NYK', 2020, data_format='PER_GAME', playoffs=False)
# okc = get_roster_stats('OKC', 2020, data_format='PER_GAME', playoffs=False)
# orl = get_roster_stats('ORL', 2020, data_format='PER_GAME', playoffs=False)
# phi = get_roster_stats('PHI', 2020, data_format='PER_GAME', playoffs=False)
# pho = get_roster_stats('PHO', 2020, data_format='PER_GAME', playoffs=False)
# por = get_roster_stats('POR', 2020, data_format='PER_GAME', playoffs=False)
# sac = get_roster_stats('SAC', 2020, data_format='PER_GAME', playoffs=False)
# sas = get_roster_stats('SAS', 2020, data_format='PER_GAME', playoffs=False)
# tor = get_roster_stats('TOR', 2020, data_format='PER_GAME', playoffs=False)
# uta = get_roster_stats('UTA', 2020, data_format='PER_GAME', playoffs=False)
# was = get_roster_stats('WAS', 2020, data_format='PER_GAME', playoffs=False)

# %%
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM','YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#             PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0  Zion Williamson    1  NOP  2019  24.0  27.8  8.8  15.0  4.8  7.4  2.7  3.6
# 1        Ja Morant    2  MEM  2019  67.0  31.0  6.7  14.0  3.6  4.6  0.8  3.1
# 2       RJ Barrett    3  NYK  2019  56.0  30.4  5.2  13.0  2.8  4.5  0.9  4.1
# 3  De'Andre Hunter    4  LAL  2019  63.0  32.0  4.4  10.8  1.7  2.3  0.7  3.8
# 4   Darius Garland    5  CLE  2019  59.0  30.9  4.7  11.8  1.1  1.2  0.5  1.4
#
#    AST  STL  BLK  TOV   PF   PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  2.1  0.7  0.4  2.5  1.8  22.5        21.7          4.6           9.8
# 1  7.3  0.9  0.3  3.3  1.6  17.8        20.5          2.8          10.1
# 2  2.6  1.0  0.3  2.2  2.2  14.3        10.9         -2.1          -0.4
# 3  1.8  0.7  0.3  1.6  2.9  12.3         7.6         -3.2          -2.5
# 4  3.9  0.7  0.1  2.6  1.6  12.3        16.5         -0.3           4.3

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         60 non-null     object
#  1   PICK           60 non-null     object
#  2   TEAM           60 non-null     object
#  3   YEAR           60 non-null     int64
#  4   G              54 non-null     float64
#  5   MP             54 non-null     float64
#  6   FG             54 non-null     float64
#  7   FGA            54 non-null     float64
#  8   FT             54 non-null     float64
#  9   FTA            54 non-null     float64
#  10  ORB            54 non-null     float64
#  11  DRB            54 non-null     float64
#  12  AST            54 non-null     float64
#  13  STL            54 non-null     float64
#  14  BLK            54 non-null     float64
#  15  TOV            54 non-null     float64
#  16  PF             54 non-null     float64
#  17  PTS            54 non-null     float64
#  18  ADVANCED_WS    58 non-null     float64
#  19  ADVANCED_BPM   58 non-null     float64
#  20  ADVANCED_VORP  58 non-null     float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 10.0+ KB

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
#             PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0  Zion Williamson    1  NOP  2019  24.0  27.8  8.8  15.0  4.8  7.4  2.7  3.6
# 1        Ja Morant    2  MEM  2019  67.0  31.0  6.7  14.0  3.6  4.6  0.8  3.1
# 2       RJ Barrett    3  NYK  2019  56.0  30.4  5.2  13.0  2.8  4.5  0.9  4.1
# 3  De'Andre Hunter    4  LAL  2019  63.0  32.0  4.4  10.8  1.7  2.3  0.7  3.8
# 4   Darius Garland    5  CLE  2019  59.0  30.9  4.7  11.8  1.1  1.2  0.5  1.4
#
#    AST  STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP  \
# 0  2.1  0.7  0.4  2.5  1.8  22.5         21.7           4.6            9.8
# 1  7.3  0.9  0.3  3.3  1.6  17.8         20.5           2.8           10.1
# 2  2.6  1.0  0.3  2.2  2.2  14.3         10.9          -2.1           -0.4
# 3  1.8  0.7  0.3  1.6  2.9  12.3          7.6          -3.2           -2.5
# 4  3.9  0.7  0.1  2.6  1.6  12.3         16.5          -0.3            4.3
#
#     PER
# 0  24.4
# 1  17.5
# 2   9.8
# 3   8.3
# 4   8.0

# %%
rookie_merge.to_csv('2019_draft_class.csv', index=False)
