# %%
pip install basketball_reference_scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2021)
draft['YEAR'] =  2021
draft
# Out:
#    PICK TEAM                  PLAYER                COLLEGE YEARS TOTALS_G  \
# 0     1  DET         Cade Cunningham         Oklahoma State     3      138
# 1     2  HOU             Jalen Green                    NaN     3      225
# 2     3  CLE             Evan Mobley                    USC     3      198
# 3     4  TOR          Scottie Barnes          Florida State     3      211
# 4     5  ORL             Jalen Suggs                Gonzaga     3      176
# 5     6  OKC             Josh Giddey                    NaN     3      210
# 6     7  GSW        Jonathan Kuminga                    NaN     3      211
# 7     8  ORL            Franz Wagner               Michigan     3      231
# 8     9  SAC         Davion Mitchell                 Baylor     3      227
# 9    10  NOP         Ziaire Williams               Stanford     3      150
# 10   11  CHO         James Bouknight                  UConn     3       79
# ...

# %%
atl = get_roster_stats('ATL', 2022, data_format='PER_GAME', playoffs=False)
bos = get_roster_stats('BOS', 2022, data_format='PER_GAME', playoffs=False)
brk = get_roster_stats('BRK', 2022, data_format='PER_GAME', playoffs=False)
cho = get_roster_stats('CHO', 2022, data_format='PER_GAME', playoffs=False)
chi = get_roster_stats('CHI', 2022, data_format='PER_GAME', playoffs=False)
cle = get_roster_stats('CLE', 2022, data_format='PER_GAME', playoffs=False)
dal = get_roster_stats('DAL', 2022, data_format='PER_GAME', playoffs=False)
den = get_roster_stats('DEN', 2022, data_format='PER_GAME', playoffs=False)
det = get_roster_stats('DET', 2022, data_format='PER_GAME', playoffs=False)
gsw = get_roster_stats('GSW', 2022, data_format='PER_GAME', playoffs=False)
hou = get_roster_stats('HOU', 2022, data_format='PER_GAME', playoffs=False)
ind = get_roster_stats('IND', 2022, data_format='PER_GAME', playoffs=False)
lac = get_roster_stats('LAC', 2022, data_format='PER_GAME', playoffs=False)
lal = get_roster_stats('LAL', 2022, data_format='PER_GAME', playoffs=False)
mem = get_roster_stats('MEM', 2022, data_format='PER_GAME', playoffs=False)
mia = get_roster_stats('MIA', 2022, data_format='PER_GAME', playoffs=False)
mil = get_roster_stats('MIL', 2022, data_format='PER_GAME', playoffs=False)
minn = get_roster_stats('MIN', 2022, data_format='PER_GAME', playoffs=False)
nop = get_roster_stats('NOP', 2022, data_format='PER_GAME', playoffs=False)
nyk = get_roster_stats('NYK', 2022, data_format='PER_GAME', playoffs=False)
okc = get_roster_stats('OKC', 2022, data_format='PER_GAME', playoffs=False)
orl = get_roster_stats('ORL', 2022, data_format='PER_GAME', playoffs=False)
phi = get_roster_stats('PHI', 2022, data_format='PER_GAME', playoffs=False)
pho = get_roster_stats('PHO', 2022, data_format='PER_GAME', playoffs=False)
sac = get_roster_stats('SAC', 2022, data_format='PER_GAME', playoffs=False)
sas = get_roster_stats('SAS', 2022, data_format='PER_GAME', playoffs=False)
tor = get_roster_stats('TOR', 2022, data_format='PER_GAME', playoffs=False)
uta = get_roster_stats('UTA', 2022, data_format='PER_GAME', playoffs=False)
was = get_roster_stats('WAS', 2022, data_format='PER_GAME', playoffs=False)

# %%
# nba_teams = ['ATL','BOS','BRK','CHO','CHI','CLE','DAL','DEN','DET','GSW',
#              'HOU','IND','LAC','LAL','MEM','MIA','MIL','MIN','NOP','NYK',
#              'OKC','ORL','PHI','PHO','POR','SAC','SAS','TOR','UTA','WAS']

# player_stat_list = []

# for team in nba_teams:
#     player_stats = get_roster_stats(team, 2023, data_format='PER_GAME', playoffs=False)
#     player_stats['TEAM'] = team
#     player_stat_list.append(player_stats)

# # roster_stats_df = pd.concat(player_stat_list,ignore_index=True)

# %%
por = get_roster_stats('POR', 2022, data_format='PER_GAME', playoffs=False)
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')
rookie_merge
# Out:
#                   PLAYER   AGE     G    GS    MP   FG   FGA    FG%   3P  3PA  \
# 0        Cade Cunningham  20.0  64.0  64.0  32.6  6.7  16.1  0.416  1.8  5.7
# 1            Jalen Green  19.0  67.0  67.0  31.9  6.1  14.2  0.426  2.3  6.8
# 2            Evan Mobley  20.0  69.0  69.0  33.8  6.1  12.0  0.508  0.3  1.3
# 3         Scottie Barnes  20.0  74.0  74.0  35.4  6.2  12.6  0.492  0.8  2.6
# 4            Jalen Suggs  20.0  48.0  45.0  27.2  4.1  11.4  0.361  0.9  4.1
# ..                   ...   ...   ...   ...   ...  ...   ...    ...  ...  ...
# 57       Balša Koprivica   NaN   NaN   NaN   NaN  NaN   NaN    NaN  NaN  NaN
# 58          Jericho Sims  23.0  41.0   5.0  13.5  1.0   1.3  0.722  0.0  0.0
# 59          RaiQuan Gray   NaN   NaN   NaN   NaN  NaN   NaN    NaN  NaN  NaN
# 60  Georgios Kalaitzakis  23.0   9.0   0.0   5.3  0.6   1.2  0.455  0.2  0.4
# 61  Georgios Kalaitzakis  23.0   4.0   4.0  41.5  6.5  14.0  0.464  2.0  5.5
#
# ...

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM','YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#             PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0  Cade Cunningham    1  DET  2021  64.0  32.6  6.7  16.1  2.2  2.6  0.9  4.6
# 1      Jalen Green    2  HOU  2021  67.0  31.9  6.1  14.2  2.8  3.5  0.5  2.9
# 2      Evan Mobley    3  CLE  2021  69.0  33.8  6.1  12.0  2.4  3.7  2.1  6.2
# 3   Scottie Barnes    4  TOR  2021  74.0  35.4  6.2  12.6  2.1  2.9  2.6  4.9
# 4      Jalen Suggs    5  ORL  2021  48.0  27.2  4.1  11.4  2.6  3.4  0.5  3.0
#
#    AST  STL  BLK  TOV   PF   PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  5.6  1.2  0.7  3.7  3.1  17.4         1.1         -0.6           1.6
# 1  2.6  0.7  0.3  2.0  1.5  17.3         5.6         -1.7           0.5
# 2  2.5  0.8  1.7  1.9  2.1  15.0        19.3          1.6           5.9
# 3  3.5  1.1  0.7  1.8  2.6  15.3        15.9          1.5           6.5
# 4  4.4  1.2  0.4  3.0  3.0  11.8         4.5         -1.4           0.7

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 61
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         62 non-null     object
#  1   PICK           62 non-null     object
#  2   TEAM           62 non-null     object
#  3   YEAR           62 non-null     int64
#  4   G              55 non-null     float64
#  5   MP             55 non-null     float64
#  6   FG             55 non-null     float64
#  7   FGA            55 non-null     float64
#  8   FT             55 non-null     float64
#  9   FTA            55 non-null     float64
#  10  ORB            55 non-null     float64
#  11  DRB            55 non-null     float64
#  12  AST            55 non-null     float64
#  13  STL            55 non-null     float64
#  14  BLK            55 non-null     float64
#  15  TOV            55 non-null     float64
#  16  PF             55 non-null     float64
# ...

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
# C:\Users\zecha\AppData\Local\Temp\ipykernel_11344\2270785795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
# C:\Users\zecha\AppData\Local\Temp\ipykernel_11344\2270785795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rookie_merge['PER'] = rookie_merge['PER'].round(1)
#             PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# ...

# %%
rookie_merge.to_csv('2021_draft_class.csv', index=False)
