# %%
import pandas as pd

# %%
draft_14 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2014_draft_class.csv")
draft_15 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2015_draft_class.csv")
draft_16 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2016_draft_class.csv")
draft_17 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2017_draft_class.csv")
draft_18 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2018_draft_class.csv")
draft_19 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2019_draft_class.csv")
draft_20 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2020_draft_class.csv")
draft_21 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2021_draft_class.csv")
draft_22 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2022_draft_class.csv")
draft_23 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2023_draft_class.csv")

# %%
rookies_eff = pd.concat([draft_14,draft_15,draft_16,draft_17,draft_18,draft_19,draft_20,draft_21,draft_22,draft_23])

# %%
rookies_eff.head()
# Out:
#            PLAYER  PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ...  AST  \
# 0  Andrew Wiggins     1  CLE  2014  82.0  36.2  6.1  13.9  4.3  5.7  ...  2.1
# 1   Jabari Parker     2  MIL  2014  25.0  29.5  5.2  10.5  1.8  2.6  ...  1.7
# 2     Joel Embiid     3  PHI  2014   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN
# 3    Aaron Gordon     4  ORL  2014  47.0  17.0  2.0   4.4  0.9  1.3  ...  0.7
# 4      Dante Exum     5  UTA  2014  82.0  22.2  1.8   5.1  0.2  0.4  ...  2.4
#
#    STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP   PER
# 0  1.0  0.6  2.2  2.3  16.9         29.1          -1.5            2.8  11.5
# 1  1.2  0.2  1.9  1.7  12.3         13.8          -0.8            2.5  12.6
# 2  NaN  NaN  NaN  NaN   NaN         63.5           7.0           31.4   NaN
# 3  0.4  0.5  0.8  1.8   5.2         42.6           0.3           11.3   9.5
# 4  0.5  0.2  1.4  1.8   4.8          5.9          -2.8           -1.2   4.0
#
# [5 rows x 22 columns]

# %%
# rookies_eff = rookies_eff.dropna()
# rookies_eff

# %%
# rookies_2017 = rookies_eff[rookies_eff['YEAR'] == 2017]
# rookies_2017

# %%
# rookies_eff.to_csv('rookie_eff.csv', index=False)

# %%
# brk = rookies_eff[rookies_eff['TEAM'] == 'BRK']
# brk

# %%
nba_teams = rookies_eff['TEAM'].unique()
nba_teams = pd.DataFrame(nba_teams, columns=['TEAM'])
nba_teams
# Out:
#    TEAM
# 0   CLE
# 1   MIL
# 2   PHI
# 3   ORL
# 4   UTA
# 5   BOS
# 6   LAL
# 7   SAC
# 8   CHO
# 9   DEN
# 10  MIN
# 11  PHO
# 12  ATL
# 13  CHI
# 14  TOR
# 15  OKC
# 16  MEM
# 17  HOU
# 18  MIA
# 19  LAC
# 20  SAS
# 21  NYK
# 22  DET
# 23  WAS
# 24  IND
# 25  DAL
# 26  POR
# 27  BRK
# 28  GSW
# 29  NOP

# %%
lottery = rookies_eff[rookies_eff['PICK'] <= 14]
# lottery.head(15)
lottery_counts = lottery['TEAM'].value_counts().reset_index()
lottery_counts = lottery_counts.rename(columns={'index':'TEAM','TEAM':'LOTTERY PICKS'})
lottery_counts
# lottery_counts.to_csv('lottery_counts.csv', index=False)
# Out:
#    TEAM  LOTTERY PICKS
# 0   ORL             11
# 1   CHO              9
# 2   SAC              9
# 3   PHO              8
# 4   NOP              7
# 5   DET              6
# 6   NYK              6
# 7   MIN              6
# 8   CLE              6
# 9   PHI              6
# 10  DEN              5
# 11  LAL              5
# 12  BOS              5
# 13  OKC              5
# 14  WAS              4
# 15  UTA              4
# 16  IND              4
# 17  SAS              4
# 18  CHI              4
# 19  ATL              4
# 20  HOU              3
# 21  GSW              3
# 22  MIA              3
# 23  DAL              3
# 24  TOR              3
# 25  LAC              2
# 26  MEM              2
# 27  MIL              2
# 28  POR              2

# %%
lottery = pd.merge(nba_teams,lottery_counts,how='left',on='TEAM')
lottery.fillna(0, inplace=True)
# lottery['count'].astype(int)
lottery = lottery.rename(columns={'count':'LOTTERY PICKS'})
lottery
# lottery.to_csv('lottery_counts.csv', index=False)
# Out:
#    TEAM  LOTTERY PICKS
# 0   CLE            6.0
# 1   MIL            2.0
# 2   PHI            6.0
# 3   ORL           11.0
# 4   UTA            4.0
# 5   BOS            5.0
# 6   LAL            5.0
# 7   SAC            9.0
# 8   CHO            9.0
# 9   DEN            5.0
# 10  MIN            6.0
# 11  PHO            8.0
# 12  ATL            4.0
# 13  CHI            4.0
# 14  TOR            3.0
# 15  OKC            5.0
# 16  MEM            2.0
# 17  HOU            3.0
# 18  MIA            3.0
# 19  LAC            2.0
# 20  SAS            4.0
# 21  NYK            6.0
# 22  DET            6.0
# 23  WAS            4.0
# 24  IND            4.0
# 25  DAL            3.0
# 26  POR            2.0
# 27  BRK            0.0
# 28  GSW            3.0
# 29  NOP            7.0

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\zecha\anaconda3\envs\geospatial\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
drop_injuries = rookies_eff.dropna()
drop_injuries.head()
# Out:
#            PLAYER  PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ...  AST  \
# 0  Andrew Wiggins     1  CLE  2014  82.0  36.2  6.1  13.9  4.3  5.7  ...  2.1
# 1   Jabari Parker     2  MIL  2014  25.0  29.5  5.2  10.5  1.8  2.6  ...  1.7
# 3    Aaron Gordon     4  ORL  2014  47.0  17.0  2.0   4.4  0.9  1.3  ...  0.7
# 4      Dante Exum     5  UTA  2014  82.0  22.2  1.8   5.1  0.2  0.4  ...  2.4
# 5    Marcus Smart     6  BOS  2014  67.0  27.0  2.6   7.1  1.2  1.9  ...  3.1
#
#    STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP   PER
# 0  1.0  0.6  2.2  2.3  16.9         29.1          -1.5            2.8  11.5
# 1  1.2  0.2  1.9  1.7  12.3         13.8          -0.8            2.5  12.6
# 3  0.4  0.5  0.8  1.8   5.2         42.6           0.3           11.3   9.5
# 4  0.5  0.2  1.4  1.8   4.8          5.9          -2.8           -1.2   4.0
# 5  1.5  0.3  1.3  2.6   7.8         33.4          -0.3            7.6   9.3
#
# [5 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=drop_injuries,x='PER', bins=50)
plt.ylabel('Number of NBA Rookies')
plt.xlabel('Player Efficiency Rating (PER)')
# Out:
# Text(0.5, 0, 'Player Efficiency Rating (PER)')

# %%
first = drop_injuries[drop_injuries['PICK'] <= 30]
second = drop_injuries[drop_injuries['PICK'] > 30]

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot the first histogram
sns.histplot(data=first, x='PER', bins=50, color = '#242841', alpha=0.5, label='First Rounders')

# Plot the second histogram
sns.histplot(data=second, x = 'PER', bins=50, color='#E95E24', alpha=0.5, label='Second Rounders')

# Add labels and legend
plt.ylabel('Number of NBA Rookies')
plt.xlabel('Player Efficiency Rating (PER)')
plt.title('Player Effiency Rating of First and Second Round Draft Picks')
plt.legend()

# Show the plot
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\first_second_round_comp.jpg')
plt.show()

# %%
below_avg = rookies_eff[rookies_eff['PER'] < 15]
pct = round((len(below_avg)/len(rookies_eff))*100, 2)
print(pct)
# Out:
# 72.18

# %%
rookies_perws = rookies_eff.dropna()

# %%
sns.scatterplot(x='PER', y='ADVANCED_WS', data=rookies_perws, color = '#242841')
plt.title('Player Efficiency Vs Average Win Share')
plt.xlabel('Player Efficiency Rating')
plt.ylabel('Player Wins Share')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\per_vs_ws.jpg')
plt.show()

# %%
perws_corr = rookies_perws.corr()
print(perws_corr)
# Out:
#                    PICK      YEAR         G        MP        FG       FGA  \
# PICK           1.000000  0.063982 -0.560102 -0.581591 -0.571026 -0.578441
# YEAR           0.063982  1.000000  0.004709  0.037100  0.074474  0.057882
# YEAR           0.031667 -0.003336 -0.004269  0.083123    -0.394815
# G              0.330658  0.518600  0.661458  0.639634     0.359266
# MP             0.413365  0.820500  0.813874  0.911588     0.324377
# FG             0.445431  0.839282  0.725242  0.991360     0.341799
# FGA            0.349570  0.876674  0.698414  0.980359     0.287700
# FT             0.381268  0.778456  0.615403  0.882631     0.324821
# FTA            0.416686  0.777352  0.627429  0.862590     0.337795
# ORB            0.697678  0.380718  0.625802  0.519080     0.291878
# DRB            0.648351  0.660021  0.738441  0.787230     0.344755
# AST            0.123239  0.834629  0.494357  0.687984     0.192331
# STL            0.299863  0.693245  0.674265  0.669692     0.237477
# BLK            1.000000  0.327010  0.558813  0.410247     0.296142
# TOV            0.327010  1.000000  0.667339  0.848336     0.238353
# PF             0.558813  0.667339  1.000000  0.713137     0.323126
# PTS            0.410247  0.848336  0.713137  1.000000     0.330340
# ADVANCED_WS    0.296142  0.238353  0.323126  0.330340     1.000000
# ADVANCED_BPM   0.349782  0.272176  0.322603  0.378774     0.554475
# ADVANCED_VORP  0.264686  0.292556  0.233520  0.352537     0.904094
# PER            0.421903  0.194681  0.264464  0.399775     0.229856
#
#                ADVANCED_BPM  ADVANCED_VORP       PER
# PICK              -0.337030      -0.279927 -0.163654
# YEAR              -0.144602      -0.278777  0.129492
# G                  0.386591       0.275624  0.189067
# MP                 0.352575       0.292089  0.248862
# FG                 0.389627       0.356309  0.423121
# FGA                0.317081       0.310974  0.291094
# FT                 0.319115       0.352741  0.373043
# FTA                0.322852       0.355539  0.362800
# ORB                0.352820       0.243130  0.500636
# DRB                0.383857       0.335300  0.394386
# AST                0.284135       0.277677  0.186369
# STL                0.342788       0.253357  0.253025
# BLK                0.349782       0.264686  0.421903
# TOV                0.272176       0.292556  0.194681
# PF                 0.322603       0.233520  0.264464
# PTS                0.378774       0.352537  0.399775
# ADVANCED_WS        0.554475       0.904094  0.229856
# ADVANCED_BPM       1.000000       0.528656  0.609915
# ADVANCED_VORP      0.528656       1.000000  0.235411
# PER                0.609915       0.235411  1.000000
# C:\Users\zecha\AppData\Local\Temp\ipykernel_7780\895529142.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   perws_corr = rookies_perws.corr()

# %%
sns.scatterplot(x='ADVANCED_VORP', y='ADVANCED_WS', data=rookies_perws, color = '#242841')
plt.title('Player Value over Replacemnet Player Vs Average Win Share')
plt.xlabel('Player Value Over Replacement')
plt.ylabel('Average Win Share')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\vorp_vs_ws.jpg')
plt.show()

# %%
sns.scatterplot(x='PER', y='ADVANCED_BPM', data=rookies_perws, color = '#242841')
plt.title('Player Efficiency Rating vs Player Box Plus/Minus')
plt.xlabel('Player Efficiency Rating')
plt.ylabel('Box Plus/Minus')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\per_vs_bpm.jpg')
plt.show()
