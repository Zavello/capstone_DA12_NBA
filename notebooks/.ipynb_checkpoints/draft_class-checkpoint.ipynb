# %%
pip install basketball_reference_scraper
# Out:
# Requirement already satisfied: basketball_reference_scraper in c:\users\zecha\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (4.12.3)
# Requirement already satisfied: bs4 in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (0.0.2)
# Requirement already satisfied: lxml in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (5.2.1)
# Requirement already satisfied: numpy in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.26.4)
# Requirement already satisfied: pandas in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.2.2)
# Requirement already satisfied: python-dateutil in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.9.0.post0)
# Requirement already satisfied: pytz in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2024.1)
# Requirement already satisfied: requests in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.32.2)
# Requirement already satisfied: six in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.16.0)
# Requirement already satisfied: soupsieve in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (2.5)
# Requirement already satisfied: Unidecode in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (1.2.0)
# Requirement already satisfied: selenium in c:\users\zecha\anaconda3\lib\site-packages (from basketball_reference_scraper) (4.24.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zecha\anaconda3\lib\site-packages (from pandas->basketball_reference_scraper) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zecha\anaconda3\lib\site-packages (from requests->basketball_reference_scraper) (2024.7.4)
# Requirement already satisfied: trio~=0.17 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (0.11.1)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\zecha\anaconda3\lib\site-packages (from selenium->basketball_reference_scraper) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (2.4.0)
# Requirement already satisfied: outcome in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\zecha\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball_reference_scraper) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\zecha\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium->basketball_reference_scraper) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\zecha\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium->basketball_reference_scraper) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\zecha\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->basketball_reference_scraper) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\zecha\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->basketball_reference_scraper) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd

# %%
d = get_shot_chart('2019-12-28', 'TOR', 'BOS')
df = pd.concat([df,pd.DataFrame.from_records([d])])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19228\1088126197.py in ?()
# ----> 1 d = get_shot_chart('2019-12-28', 'TOR', 'BOS')
#       2 df = pd.concat([df,pd.DataFrame.from_records([d])])
#       3 df
#
# ~\anaconda3\Lib\site-packages\basketball_reference_scraper\shot_charts.py in ?(date, team1, team2)
#      48             location = get_location(div.attrs['style'])
#      49             description = get_description(div.attrs['tip'])
#      50             shot_d = {**location, **description}
#      51             shot_df = pd.DataFrame.from_dict([shot_d])
# ---> 52             df1 = df1.append(shot_df)
#      53         df1 = df1.reset_index()
#      54         df1 = df1.drop('index', axis=1)
#      55         df2 = pd.DataFrame()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
draft = get_draft_class(2023)
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM                   PLAYER            COLLEGE YEARS TOTALS_G  \
# 0     1  SAS        Victor Wembanyama                NaN     1       71
# 1     2  CHO           Brandon Miller            Alabama     1       74
# 2     3  POR          Scoot Henderson                NaN     1       62
# 3     4  HOU            Amen Thompson                NaN     1       62
# 4     5  DET           Ausar Thompson                NaN     1       63
# 5     6  ORL            Anthony Black           Arkansas     1       69
# 6     7  IND          Bilal Coulibaly                NaN     1       63
# 7     8  WAS            Jarace Walker            Houston     1       33
# 8     9  UTA         Taylor Hendricks    Central Florida     1       40
# 9    10  DAL            Cason Wallace           Kentucky     1       82
# 10   11  ORL              Jett Howard           Michigan     1       18
# 11   12  OKC         Dereck Lively II               Duke     1       55
# 12   13  TOR              Gradey Dick             Kansas     1       60
# 13   14  NOP           Jordan Hawkins              UConn     1       67
# 14   15  ATL              Kobe Bufkin           Michigan     1       17
# 15   16  UTA           Keyonte George             Baylor     1       75
# 16   17  LAL      Jalen Hood-Schifino            Indiana     1       21
# 17   18  MIA         Jaime Jaquez Jr.               UCLA     1       75
# 18   19  GSW       Brandin Podziemski        Santa Clara     1       74
# 19   20  HOU             Cam Whitmore          Villanova     1       47
# 20   21  BRK             Noah Clowney            Alabama     1       23
# 21   22  BRK          Dariq Whitehead               Duke     1        2
# 22   23  POR              Kris Murray               Iowa     1       62
# 23   24  SAC  Olivier-Maxence Prosper          Marquette     1       40
# 24   25  MEM            Marcus Sasser            Houston     1       71
# 25   26  IND             Ben Sheppard            Belmont     1       57
# 26   27  CHO           Nick Smith Jr.           Arkansas     1       51
# 27   28  UTA         Brice Sensabaugh         Ohio State     1       32
# 28   29  IND         Julian Strawther            Gonzaga     1       50
# 29   30  LAC               Kobe Brown           Missouri     1       44
# 32   31  DET              James Nnaji                NaN   NaN      NaN
# 33   32  IND            Jalen Pickett         Penn State     1       27
# 34   33  SAS           Leonard Miller                NaN     1       17
# 35   34  CHO              Colby Jones             Xavier     1       30
# 36   35  BOS          Julian Phillips          Tennessee     1       40
# 37   36  ORL        Andre Jackson Jr.              UConn     1       57
# 38   37  OKC             Hunter Tyson            Clemson     1       18
# 39   38  SAC             Jordan Walsh           Arkansas     1        9
# 40   39  CHO           Mouhamed Gueye   Washington State     1        6
# 41   40  DEN            Maxwell Lewis         Pepperdine     1       34
# 42   41  CHO             Amari Bailey               UCLA     1       10
# 43   42  WAS         Tristan Vukcevic                NaN     1       10
# 44   43  POR             Rayan Rupert                NaN     1       39
# 45   44  SAS             Sidy Cissoko                NaN     1       12
# 46   45  MEM            GG Jackson II     South Carolina     1       48
# 47   46  ATL               Seth Lundy         Penn State     1        9
# 48   47  LAL              Mojave King                NaN   NaN      NaN
# 49   48  LAC            Jordan Miller         Miami (FL)     1        8
# 50   49  CLE              Emoni Bates   Eastern Michigan     1       15
# 51   50  OKC         Keyontae Johnson       Kansas State     1        9
# 52   51  BRK             Jalen Wilson             Kansas     1       43
# 53   52  PHO           Toumani Camara             Dayton     1       70
# 54   53  MIN             Jaylen Clark               UCLA   NaN      NaN
# 55   54  SAC            Jalen Slawson  Furman University     1       12
# 56   55  IND              Isaiah Wong         Miami (FL)     1        1
# 57   56  MEM          Tarik Biberovic                NaN   NaN      NaN
# 58   57  WAS     Trayce Jackson-Davis            Indiana     1       68
# 59   58  MIL         Chris Livingston           Kentucky     1       21
#
#    TOTALS_MP TOTALS_PTS TOTALS_TRB TOTALS_AST  ... SHOOTING_3P% SHOOTING_FT%  \
# 0       2106       1522        755        274  ...         .325         .796
# 1       2383       1279        315        175  ...         .373         .827
# 2       1765        868        194        336  ...         .325         .819
# 3       1388        592        409        163  ...         .138         .684
# 4       1583        556        402        120  ...         .186         .597
# 5       1164        316        139         91  ...         .394         .613
# 6       1715        532        256        110  ...         .346         .702
# 7        340        120         63         40  ...         .400         .889
# 8        856        292        185         32  ...         .379         .793
# 9       1692        561        187        120  ...         .419         .784
# 10        67         29          7          6  ...         .280         .500
# 11      1294        483        378         60  ...         .000         .506
# 12      1268        510        132         68  ...         .365         .863
# 13      1160        524        148         70  ...         .366         .838
# 14       196         81         33         27  ...         .225         .500
# 15      2023        974        211        332  ...         .334         .848
# 16       109         34         13          8  ...         .133         .600
# 17      2113        889        285        195  ...         .322         .811
# 18      1968        682        427        273  ...         .385         .633
# 19       880        579        180         33  ...         .359         .679
# 20       370        133         81         18  ...         .364         .700
# 21        24          3          4          3  ...         .000         .500
# 22      1348        376        224         80  ...         .268         .661
# 23       336        121         79         22  ...         .289         .683
# 24      1351        586        125        236  ...         .375         .879
# 25       814        252         89         53  ...         .314         .885
# 26       729        302         72         59  ...         .432         .867
# 27       584        241        102         55  ...         .296         .902
# 28       545        227         61         47  ...         .297         .710
# 29       394         89         62         25  ...         .292         .500
# 32       NaN        NaN        NaN        NaN  ...          NaN          NaN
# 33       122         42         14         21  ...         .360         .750
# 34        52         29         20          8  ...         .400         .500
# 35       192         64         40         20  ...         .091         .545
# 36       323         89         36         13  ...         .316         .684
# 37       572        125        113         50  ...         .370         .727
# 38        48         20          9          2  ...         .286          NaN
# 39        83         15         20          5  ...         .222         .500
# 40        73         24         22          4  ...         .333         .833
# 41       103         11          4          6  ...         .111         .667
# 42        65         23          9          7  ...         .125         .857
# 43       153         85         36         13  ...         .278         .773
# 44       633        155         92         62  ...         .359         .760
# 45       141         45         22         10  ...         .083         .800
# 46      1233        699        196         59  ...         .357         .752
# 47        52         14          7          0  ...         .231         .750
# 48       NaN        NaN        NaN        NaN  ...          NaN          NaN
# 49        28         13          5          0  ...         .500        1.000
# 50       133         41         14         10  ...         .303         .250
# 51        66         11         10          4  ...         .333          NaN
# 52       664        214        131         45  ...         .324         .826
# 53      1739        527        343         87  ...         .337         .758
# 54       NaN        NaN        NaN        NaN  ...          NaN          NaN
# 55        37          8          7          2  ...         .000          NaN
# 56         4          2          0          0  ...         .000          NaN
# 57       NaN        NaN        NaN        NaN  ...          NaN          NaN
# 58      1130        540        341         82  ...         .000         .561
# 59        90         26         21          5  ...         .200         .750
#
#    PER_GAME_MP PER_GAME_PTS PER_GAME_TRB PER_GAME_AST ADVANCED_WS  \
# 0         29.7         21.4         10.6          3.9         3.7
# 1         32.2         17.3          4.3          2.4         0.8
# 2         28.5         14.0          3.1          5.4        -1.7
# 3         22.4          9.5          6.6          2.6         4.3
# 4         25.1          8.8          6.4          1.9         1.8
# 5         16.9          4.6          2.0          1.3         1.6
# 6         27.2          8.4          4.1          1.7         0.4
# 7         10.3          3.6          1.9          1.2         0.4
# 8         21.4          7.3          4.6          0.8         1.2
# 9         20.6          6.8          2.3          1.5         4.0
# 10         3.7          1.6          0.4          0.3         0.0
# 11        23.5          8.8          6.9          1.1         4.9
# 12        21.1          8.5          2.2          1.1         0.3
# 13        17.3          7.8          2.2          1.0         1.3
# 14        11.5          4.8          1.9          1.6        -0.1
# 15        27.0         13.0          2.8          4.4        -0.3
# 16         5.2          1.6          0.6          0.4        -0.5
# 17        28.2         11.9          3.8          2.6         4.0
# 18        26.6          9.2          5.8          3.7         4.1
# 19        18.7         12.3          3.8          0.7         1.5
# 20        16.1          5.8          3.5          0.8         0.9
# 21        12.0          1.5          2.0          1.5         0.0
# 22        21.7          6.1          3.6          1.3         0.7
# 23         8.4          3.0          2.0          0.6         0.5
# 24        19.0          8.3          1.8          3.3         0.9
# 25        14.3          4.4          1.6          0.9         0.8
# 26        14.3          5.9          1.4          1.2        -0.5
# 27        18.3          7.5          3.2          1.7        -0.3
# 28        10.9          4.5          1.2          0.9         0.2
# 29         9.0          2.0          1.4          0.6         0.5
# 32         NaN          NaN          NaN          NaN         NaN
# 33         4.5          1.6          0.5          0.8         0.2
# 34         3.1          1.7          1.2          0.5         0.3
# 35         6.4          2.1          1.3          0.7         0.0
# 36         8.1          2.2          0.9          0.3         0.2
# 37        10.0          2.2          2.0          0.9         1.0
# 38         2.7          1.1          0.5          0.1         0.0
# 39         9.2          1.7          2.2          0.6         0.2
# 40        12.2          4.0          3.7          0.7         0.2
# 41         3.0          0.3          0.1          0.2        -0.4
# 42         6.5          2.3          0.9          0.7        -0.1
# 43        15.3          8.5          3.6          1.3         0.1
# 44        16.2          4.0          2.4          1.6        -0.1
# 45        11.8          3.8          1.8          0.8         0.3
# 46        25.7         14.6          4.1          1.2         1.2
# 47         5.8          1.6          0.8          0.0        -0.1
# 48         NaN          NaN          NaN          NaN         NaN
# 49         3.5          1.6          0.6          0.0         0.1
# 50         8.9          2.7          0.9          0.7        -0.3
# 51         7.3          1.2          1.1          0.4        -0.1
# 52        15.4          5.0          3.0          1.0         1.1
# 53        24.8          7.5          4.9          1.2         2.0
# 54         NaN          NaN          NaN          NaN         NaN
# 55         3.1          0.7          0.6          0.2         0.0
# 56         4.0          2.0          0.0          0.0         0.0
# 57         NaN          NaN          NaN          NaN         NaN
# 58        16.6          7.9          5.0          1.2         4.8
# 59         4.3          1.2          1.0          0.2         0.1
#
#    ADVANCED_WS/48 ADVANCED_BPM ADVANCED_VORP
# 0            .085          5.2           3.8
# 1            .015         -2.6          -0.3
# 2           -.045         -5.8          -1.7
# 3            .149          1.8           1.3
# 4            .053         -2.2          -0.1
# 5            .067         -3.0          -0.3
# 6            .013         -4.2          -0.9
# 7            .058          0.2           0.2
# 8            .070         -1.6           0.1
# 9            .115          0.1           0.9
# 10           .005         -1.8           0.0
# 11           .183          0.5           0.8
# 12           .010         -5.4          -1.1
# 13           .053         -3.1          -0.3
# 14          -.031         -4.5          -0.1
# 15          -.008         -4.4          -1.2
# 16          -.222        -16.1          -0.4
# 17           .092         -1.9           0.1
# 18           .100         -0.1           0.9
# 19           .082          0.1           0.5
# 20           .111         -0.7           0.1
# 21          -.030         -7.9           0.0
# 22           .024         -3.6          -0.6
# 23           .076         -2.9          -0.1
# 24           .033         -2.6          -0.2
# 25           .046         -3.4          -0.3
# 26          -.036         -5.9          -0.7
# 27          -.024         -5.5          -0.5
# 28           .015         -6.0          -0.6
# 29           .055         -3.8          -0.2
# 32            NaN          NaN           NaN
# 33           .065         -3.3           0.0
# 34           .323          9.6           0.2
# 35           .007         -5.0          -0.1
# 36           .031         -5.3          -0.3
# 37           .081         -3.6          -0.2
# 38           .007         -8.9          -0.1
# 39           .089         -3.8           0.0
# 40           .127         -1.5           0.0
# 41          -.195        -13.5          -0.3
# 42          -.044         -8.3          -0.1
# 43           .045         -3.6          -0.1
# 44          -.009         -6.7          -0.8
# 45           .110         -2.7           0.0
# 46           .048         -2.0           0.0
# 47          -.092        -12.7          -0.1
# 48            NaN          NaN           NaN
# 49           .116         -3.8           0.0
# 50          -.092         -9.2          -0.2
# 51          -.068         -9.8          -0.1
# 52           .077         -2.9          -0.2
# 53           .055         -3.1          -0.5
# 54            NaN          NaN           NaN
# 55           .058         -6.4           0.0
# 56          -.277        -19.0           0.0
# 57            NaN          NaN           NaN
# 58           .205          2.8           1.4
# 59           .027         -8.0          -0.1
#
# [58 rows x 21 columns]

# %%
print(pd.__version__)
# Out:
# 2.2.2
