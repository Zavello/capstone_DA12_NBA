# %%
pip install basketball_reference_scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2016)
draft['YEAR'] =  2016
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM                   PLAYER           COLLEGE YEARS TOTALS_G  \
# 0     1  PHI              Ben Simmons               LSU     6      332
# 1     2  LAL           Brandon Ingram              Duke     8      477
# 2     3  BOS             Jaylen Brown        California     8      540
# 3     4  PHO            Dragan Bender               NaN     4      187
# 4     5  MIN                Kris Dunn        Providence     8      333
# 5     6  NOP              Buddy Hield          Oklahoma     8      632
# 6     7  DEN             Jamal Murray          Kentucky     7      469
# 7     8  SAC          Marquese Chriss        Washington     6      292
# ...

# %%
atl = get_roster_stats('ATL', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
bos = get_roster_stats('BOS', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
brk = get_roster_stats('BRK', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cho = get_roster_stats('CHO', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
chi = get_roster_stats('CHI', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cle = get_roster_stats('CLE', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
dal = get_roster_stats('DAL', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
den = get_roster_stats('DEN', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
det = get_roster_stats('DET', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
gsw = get_roster_stats('GSW', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
hou = get_roster_stats('HOU', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
ind = get_roster_stats('IND', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
lac = get_roster_stats('LAC', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
lal = get_roster_stats('LAL', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
mem = get_roster_stats('MEM', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
mia = get_roster_stats('MIA', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mil = get_roster_stats('MIL', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
minn = get_roster_stats('MIN', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
nop = get_roster_stats('NOP', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nyk = get_roster_stats('NYK', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
okc = get_roster_stats('OKC', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
orl = get_roster_stats('ORL', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
phi = get_roster_stats('PHI', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
pho = get_roster_stats('PHO', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
por = get_roster_stats('POR', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sac = get_roster_stats('SAC', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sas = get_roster_stats('SAS', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
tor = get_roster_stats('TOR', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
uta = get_roster_stats('UTA', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
was = get_roster_stats('WAS', 2017, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM','YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#            PLAYER PICK TEAM  YEAR     G    MP   FG  FGA   FT  FTA  ORB  DRB  \
# 0     Ben Simmons    1  PHI  2016   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  Brandon Ingram    2  LAL  2016  79.0  28.8  3.5  8.7  1.7  2.7  0.8  3.2
# 2    Jaylen Brown    3  BOS  2016  78.0  17.2  2.5  5.4  1.1  1.6  0.6  2.2
# 3   Dragan Bender    4  PHO  2016  43.0  13.3  1.3  3.7  0.1  0.3  0.5  1.9
# 4       Kris Dunn    5  MIN  2016  78.0  17.1  1.5  4.0  0.5  0.8  0.3  1.8
#
#    AST  STL  BLK  TOV   PF  PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  NaN  NaN  NaN  NaN  NaN  NaN        33.6          3.3          14.6
# 1  2.1  0.6  0.5  1.5  2.0  9.4        27.2          0.1           8.4
# 2  0.8  0.4  0.2  0.9  1.8  6.6        35.3          0.4           9.7
# 3  0.5  0.2  0.5  0.7  1.7  3.4         0.5         -3.9          -1.9
# 4  2.4  1.0  0.5  1.1  2.3  3.8         7.7         -1.5           1.0

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         61 non-null     object
#  1   PICK           61 non-null     object
#  2   TEAM           61 non-null     object
#  3   YEAR           61 non-null     int64
#  4   G              46 non-null     float64
#  5   MP             46 non-null     float64
#  6   FG             46 non-null     float64
#  7   FGA            46 non-null     float64
#  8   FT             46 non-null     float64
#  9   FTA            46 non-null     float64
#  10  ORB            46 non-null     float64
#  11  DRB            46 non-null     float64
#  12  AST            46 non-null     float64
#  13  STL            46 non-null     float64
#  14  BLK            46 non-null     float64
#  15  TOV            46 non-null     float64
#  16  PF             46 non-null     float64
# ...

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
#            PLAYER PICK TEAM  YEAR     G    MP   FG  FGA   FT  FTA  ORB  DRB  \
# 0     Ben Simmons    1  PHI  2016   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  Brandon Ingram    2  LAL  2016  79.0  28.8  3.5  8.7  1.7  2.7  0.8  3.2
# 2    Jaylen Brown    3  BOS  2016  78.0  17.2  2.5  5.4  1.1  1.6  0.6  2.2
# 3   Dragan Bender    4  PHO  2016  43.0  13.3  1.3  3.7  0.1  0.3  0.5  1.9
# 4       Kris Dunn    5  MIN  2016  78.0  17.1  1.5  4.0  0.5  0.8  0.3  1.8
#
#    AST  STL  BLK  TOV   PF  PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP  PER
# 0  NaN  NaN  NaN  NaN  NaN  NaN         33.6           3.3           14.6  NaN
# 1  2.1  0.6  0.5  1.5  2.0  9.4         27.2           0.1            8.4  7.6
# 2  0.8  0.4  0.2  0.9  1.8  6.6         35.3           0.4            9.7  9.2
# 3  0.5  0.2  0.5  0.7  1.7  3.4          0.5          -3.9           -1.9  4.5
# 4  2.4  1.0  0.5  1.1  2.3  3.8          7.7          -1.5            1.0  7.2

# %%
rookie_merge.to_csv('2016_draft_class.csv', index=False)
