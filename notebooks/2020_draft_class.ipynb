# %%
pip install basketball_reference_scraper
# Out:
# ...
#
# ...

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2020)
draft['YEAR'] =  2020
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM              PLAYER                COLLEGE YEARS TOTALS_G  \
# 0     1  MIN     Anthony Edwards                Georgia     4      302
# 1     2  GSW       James Wiseman                Memphis     3      147
# 2     3  CHO         LaMelo Ball                    NaN     4      184
# 3     4  CHI    Patrick Williams          Florida State     4      213
# 4     5  CLE         Isaac Okoro                 Auburn     4      279
# 5     6  ATL      Onyeka Okongwu                    USC     4      233
# 6     7  DET       Killian Hayes                    NaN     4      210
# 7     8  NYK          Obi Toppin                 Dayton     4      283
# ...

# %%
atl = get_roster_stats('ATL', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
bos = get_roster_stats('BOS', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
brk = get_roster_stats('BRK', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
cho = get_roster_stats('CHO', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
chi = get_roster_stats('CHI', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cle = get_roster_stats('CLE', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
dal = get_roster_stats('DAL', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
den = get_roster_stats('DEN', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
det = get_roster_stats('DET', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
gsw = get_roster_stats('GSW', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
hou = get_roster_stats('HOU', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
ind = get_roster_stats('IND', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
lac = get_roster_stats('LAC', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
lal = get_roster_stats('LAL', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
mem = get_roster_stats('MEM', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
mia = get_roster_stats('MIA', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mil = get_roster_stats('MIL', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
minn = get_roster_stats('MIN', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nop = get_roster_stats('NOP', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nyk = get_roster_stats('NYK', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
okc = get_roster_stats('OKC', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
orl = get_roster_stats('ORL', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
phi = get_roster_stats('PHI', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
pho = get_roster_stats('PHO', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
por = get_roster_stats('POR', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
sac = get_roster_stats('SAC', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sas = get_roster_stats('SAS', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
tor = get_roster_stats('TOR', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
uta = get_roster_stats('UTA', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
was = get_roster_stats('WAS', 2021, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
# atl = get_roster_stats('ATL', 2021, data_format='PER_GAME', playoffs=False)
# bos = get_roster_stats('BOS', 2021, data_format='PER_GAME', playoffs=False)
# brk = get_roster_stats('BRK', 2021, data_format='PER_GAME', playoffs=False)
# cho = get_roster_stats('CHO', 2021, data_format='PER_GAME', playoffs=False)
# chi = get_roster_stats('CHI', 2021, data_format='PER_GAME', playoffs=False)
# cle = get_roster_stats('CLE', 2021, data_format='PER_GAME', playoffs=False)
# dal = get_roster_stats('DAL', 2021, data_format='PER_GAME', playoffs=False)
# den = get_roster_stats('DEN', 2021, data_format='PER_GAME', playoffs=False)
# det = get_roster_stats('DET', 2021, data_format='PER_GAME', playoffs=False)
# gsw = get_roster_stats('GSW', 2021, data_format='PER_GAME', playoffs=False)
# hou = get_roster_stats('HOU', 2021, data_format='PER_GAME', playoffs=False)
# ind = get_roster_stats('IND', 2021, data_format='PER_GAME', playoffs=False)
# lac = get_roster_stats('LAC', 2021, data_format='PER_GAME', playoffs=False)
# lal = get_roster_stats('LAL', 2021, data_format='PER_GAME', playoffs=False)
# mem = get_roster_stats('MEM', 2021, data_format='PER_GAME', playoffs=False)
# mia = get_roster_stats('MIA', 2021, data_format='PER_GAME', playoffs=False)
# mil = get_roster_stats('MIL', 2021, data_format='PER_GAME', playoffs=False)
# minn = get_roster_stats('MIN', 2021, data_format='PER_GAME', playoffs=False)
# nop = get_roster_stats('NOP', 2021, data_format='PER_GAME', playoffs=False)
# nyk = get_roster_stats('NYK', 2021, data_format='PER_GAME', playoffs=False)
# okc = get_roster_stats('OKC', 2021, data_format='PER_GAME', playoffs=False)
# orl = get_roster_stats('ORL', 2021, data_format='PER_GAME', playoffs=False)
# phi = get_roster_stats('PHI', 2021, data_format='PER_GAME', playoffs=False)
# pho = get_roster_stats('PHO', 2021, data_format='PER_GAME', playoffs=False)
# por = get_roster_stats('POR', 2021, data_format='PER_GAME', playoffs=False)
# sac = get_roster_stats('SAC', 2021, data_format='PER_GAME', playoffs=False)
# sas = get_roster_stats('SAS', 2021, data_format='PER_GAME', playoffs=False)
# tor = get_roster_stats('TOR', 2021, data_format='PER_GAME', playoffs=False)
# uta = get_roster_stats('UTA', 2021, data_format='PER_GAME', playoffs=False)
# was = get_roster_stats('WAS', 2021, data_format='PER_GAME', playoffs=False)

# %%
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')
rookie_merge
# Out:
#               PLAYER AGE   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  \
# 0    Anthony Edwards  19  72  55  32.1  7.0  16.8  0.417  2.4  7.2  0.329
# 1      James Wiseman  19  39  27  21.4  4.9   9.4  0.519  0.3  1.0  0.316
# 2        LaMelo Ball  19  51  31  28.8  5.7  13.2  0.436  1.8  5.1  0.352
# 3   Patrick Williams  19  71  71  27.9  3.6   7.4  0.483  0.8  1.9  0.391
# 4        Isaac Okoro  20  67  67  32.4  3.5   8.3   0.42  0.9  3.2   0.29
# ..               ...  ..  ..  ..   ...  ...   ...    ...  ...  ...    ...
# 56      Grant Riller  23   7   0   3.9  1.1   1.7  0.667  0.3  0.6    0.5
# 57      Reggie Perry  20  26   0   8.1  1.2   3.0   0.41  0.2  0.8   0.19
# 58         Paul Reed  21  26   0   6.8  1.6   3.0  0.538  0.0  0.2    0.0
# 59      Jalen Harris  22  13   2  13.2  2.8   5.5    0.5  1.3  2.8  0.472
# 60       Sam Merrill  24  30   2   7.8  1.1   2.4  0.444  0.7  1.6  0.447
#
#      2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  AST  STL  BLK  \
# ...

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM','YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#              PLAYER PICK TEAM  YEAR   G    MP   FG   FGA   FT  FTA  ORB  DRB  \
# 0   Anthony Edwards    1  MIN  2020  72  32.1  7.0  16.8  2.9  3.8  0.8  3.8
# 1     James Wiseman    2  GSW  2020  39  21.4  4.9   9.4  1.4  2.2  1.4  4.4
# 2       LaMelo Ball    3  CHO  2020  51  28.8  5.7  13.2  2.5  3.2  1.2  4.7
# 3  Patrick Williams    4  CHI  2020  71  27.9  3.6   7.4  1.3  1.8  0.9  3.7
# 4       Isaac Okoro    5  CLE  2020  67  32.4  3.5   8.3  1.7  2.3  1.0  2.1
#
#    AST  STL  BLK  TOV   PF   PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  2.9  1.1  0.5  2.2  1.8  19.3        16.5          0.9           7.7
# 1  0.7  0.3  0.9  1.5  3.1  11.5         4.3         -3.9          -1.4
# 2  6.1  1.6  0.4  2.8  2.7  15.7        11.6          2.8           7.1
# 3  1.4  0.9  0.6  1.4  1.8   9.2         8.0         -1.9           0.2
# 4  1.9  0.9  0.4  1.3  2.8   9.6        13.5         -2.2          -0.4

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         61 non-null     object
#  1   PICK           61 non-null     object
#  2   TEAM           61 non-null     object
#  3   YEAR           61 non-null     int64
#  4   G              56 non-null     float64
#  5   MP             56 non-null     float64
#  6   FG             56 non-null     float64
#  7   FGA            56 non-null     float64
#  8   FT             56 non-null     float64
#  9   FTA            56 non-null     float64
#  10  ORB            56 non-null     float64
#  11  DRB            56 non-null     float64
#  12  AST            56 non-null     float64
#  13  STL            56 non-null     float64
#  14  BLK            56 non-null     float64
#  15  TOV            56 non-null     float64
#  16  PF             56 non-null     float64
# ...

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
# C:\Users\zecha\AppData\Local\Temp\ipykernel_15808\2270785795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
# C:\Users\zecha\AppData\Local\Temp\ipykernel_15808\2270785795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rookie_merge['PER'] = rookie_merge['PER'].round(1)
#              PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  \
# ...

# %%
rookie_merge.to_csv('2020_draft_class.csv', index=False)
