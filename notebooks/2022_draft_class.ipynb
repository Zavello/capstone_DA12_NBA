# %%
pip install basketball_reference_scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.box_scores import get_box_scores
from basketball_reference_scraper.pbp import get_pbp
from basketball_reference_scraper.shot_charts import get_shot_chart
from basketball_reference_scraper.injury_report import get_injury_report
from basketball_reference_scraper.drafts import get_draft_class
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
draft = get_draft_class(2022)
draft['YEAR'] =  2022
draft
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\drafts.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    PICK TEAM               PLAYER         COLLEGE YEARS TOTALS_G TOTALS_MP  \
# 0     1  ORL       Paolo Banchero            Duke     2      152      5229
# 1     2  OKC        Chet Holmgren         Gonzaga     1       82      2413
# 2     3  HOU     Jabari Smith Jr.          Auburn     2      155      4875
# 3     4  SAC        Keegan Murray            Iowa     2      157      4970
# 4     5  DET           Jaden Ivey          Purdue     2      151      4521
# 5     6  IND   Bennedict Mathurin         Arizona     2      137      3760
# 6     7  POR       Shaedon Sharpe        Kentucky     2      112      2838
# 7     8  NOP        Dyson Daniels             NaN     2      120      2400
# ...

# %%
atl = get_roster_stats('ATL', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
bos = get_roster_stats('BOS', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
brk = get_roster_stats('BRK', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cho = get_roster_stats('CHO', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
chi = get_roster_stats('CHI', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
cle = get_roster_stats('CLE', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
dal = get_roster_stats('DAL', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
den = get_roster_stats('DEN', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
det = get_roster_stats('DET', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
gsw = get_roster_stats('GSW', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
hou = get_roster_stats('HOU', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
ind = get_roster_stats('IND', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
lac = get_roster_stats('LAC', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
lal = get_roster_stats('LAL', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
mem = get_roster_stats('MEM', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
mia = get_roster_stats('MIA', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
mil = get_roster_stats('MIL', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
minn = get_roster_stats('MIN', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nop = get_roster_stats('NOP', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
nyk = get_roster_stats('NYK', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]

# %%
okc = get_roster_stats('OKC', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
orl = get_roster_stats('ORL', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
phi = get_roster_stats('PHI', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
pho = get_roster_stats('PHO', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
por = get_roster_stats('POR', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sac = get_roster_stats('SAC', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
sas = get_roster_stats('SAS', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
tor = get_roster_stats('TOR', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
uta = get_roster_stats('UTA', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# ...

# %%
was = get_roster_stats('WAS', 2023, data_format='PER_GAME', playoffs=False)
# Out:
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\teams.py:116: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table)[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]
# C:\Users\zecha\anaconda3\Lib\site-packages\basketball_reference_scraper\utils.py:118: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   team_df = pd.read_html(str(table))[0]

# %%
roster_stats_df = pd.concat([atl,bos,brk,cho,chi,cle,dal,den,det,gsw,hou,ind,lac,lal,mem,mia,mil,minn,nop,nyk,okc,orl,phi,pho,por,sac,sas,tor,uta,was], ignore_index=True)

# %%
rookie_merge = pd.merge(roster_stats_df,draft,how='right',on='PLAYER')

# %%
per_stats = ['PLAYER', 'PICK', 'TEAM', 'YEAR', 'G','MP','FG','FGA','FT','FTA','ORB',
             'DRB','AST','STL','BLK','TOV','PF','PTS','ADVANCED_WS',
            'ADVANCED_BPM','ADVANCED_VORP']
rookie_merge = rookie_merge[per_stats]
rookie_merge.head()
# Out:
#              PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  \
# 0    Paolo Banchero    1  ORL  2022  72.0  33.8  6.7  15.6  5.5  7.4  1.2
# 1     Chet Holmgren    2  OKC  2022   NaN   NaN  NaN   NaN  NaN  NaN  NaN
# 2  Jabari Smith Jr.    3  HOU  2022  79.0  31.0  4.6  11.3  2.1  2.6  1.5
# 3     Keegan Murray    4  SAC  2022  80.0  29.8  4.4   9.8  0.8  1.0  1.1
# 4        Jaden Ivey    5  DET  2022  74.0  31.1  5.5  13.3  3.6  4.8  1.0
#
#    DRB  AST  STL  BLK  TOV   PF   PTS ADVANCED_WS ADVANCED_BPM ADVANCED_VORP
# 0  5.7  3.7  0.8  0.5  2.8  2.2  20.0         7.6          0.0           2.7
# 1  NaN  NaN  NaN  NaN  NaN  NaN   NaN         8.9          3.4           3.3
# 2  5.7  1.3  0.5  0.9  1.3  2.9  12.8         7.5         -2.0           0.0
# 3  3.5  1.2  0.8  0.5  0.8  2.0  12.2         9.5         -0.7           1.6
# 4  2.9  5.2  0.8  0.2  3.2  3.3  16.3         0.4         -3.2          -1.4

# %%
rookie_merge[per_stats[4:]] = rookie_merge[per_stats[4:]].apply(pd.to_numeric, errors='coerce')
rookie_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER         58 non-null     object
#  1   PICK           58 non-null     object
#  2   TEAM           58 non-null     object
#  3   YEAR           58 non-null     int64
#  4   G              47 non-null     float64
#  5   MP             47 non-null     float64
#  6   FG             47 non-null     float64
#  7   FGA            47 non-null     float64
#  8   FT             47 non-null     float64
#  9   FTA            47 non-null     float64
#  10  ORB            47 non-null     float64
#  11  DRB            47 non-null     float64
#  12  AST            47 non-null     float64
#  13  STL            47 non-null     float64
#  14  BLK            47 non-null     float64
#  15  TOV            47 non-null     float64
#  16  PF             47 non-null     float64
# ...

# %%
rookie_merge['PER'] = (0.68+(26.77*rookie_merge.FG)-(35.58*rookie_merge.FGA)+(26.32*rookie_merge.FT)-
                       (25.47*rookie_merge.FTA)+(42.74*rookie_merge.ORB)+(11.45*rookie_merge.DRB)+
                       (29.7*rookie_merge.AST)+(47.3*rookie_merge.STL)+(38*rookie_merge.BLK)-(47.9*rookie_merge.TOV)-
                       (18.8*rookie_merge.PF)+(41.1*rookie_merge.PTS))/rookie_merge.MP
rookie_merge['PER'] = rookie_merge['PER'].round(1)
rookie_merge.head()
# Out:
#              PLAYER PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ORB  \
# 0    Paolo Banchero    1  ORL  2022  72.0  33.8  6.7  15.6  5.5  7.4  1.2
# 1     Chet Holmgren    2  OKC  2022   NaN   NaN  NaN   NaN  NaN  NaN  NaN
# 2  Jabari Smith Jr.    3  HOU  2022  79.0  31.0  4.6  11.3  2.1  2.6  1.5
# 3     Keegan Murray    4  SAC  2022  80.0  29.8  4.4   9.8  0.8  1.0  1.1
# 4        Jaden Ivey    5  DET  2022  74.0  31.1  5.5  13.3  3.6  4.8  1.0
#
#    DRB  AST  STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  \
# 0  5.7  3.7  0.8  0.5  2.8  2.2  20.0          7.6           0.0
# 1  NaN  NaN  NaN  NaN  NaN  NaN   NaN          8.9           3.4
# 2  5.7  1.3  0.5  0.9  1.3  2.9  12.8          7.5          -2.0
# 3  3.5  1.2  0.8  0.5  0.8  2.0  12.2          9.5          -0.7
# 4  2.9  5.2  0.8  0.2  3.2  3.3  16.3          0.4          -3.2
#
#    ADVANCED_VORP   PER
# 0            2.7  15.1
# 1            3.3   NaN
# 2            0.0  11.2
# 3            1.6  12.4
# ...

# %%
rookie_merge.to_csv('2022_draft_class.csv', index=False)
