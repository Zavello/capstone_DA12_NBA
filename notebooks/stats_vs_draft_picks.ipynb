# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
draft_14 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2014_draft_class.csv")
draft_15 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2015_draft_class.csv")
draft_16 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2016_draft_class.csv")
draft_17 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2017_draft_class.csv")
draft_18 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2018_draft_class.csv")
draft_19 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2019_draft_class.csv")
draft_20 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2020_draft_class.csv")
draft_21 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2021_draft_class.csv")
draft_22 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2022_draft_class.csv")
draft_23 = pd.read_csv(r"C:\da12\projects\capstone\capstone_DA12_NBA\notebooks\2023_draft_class.csv")

# %%
rookies_eff = pd.concat([draft_14,draft_15,draft_16,draft_17,draft_18,draft_19,draft_20,draft_21,draft_22,draft_23])

# %%
rookies_eff = rookies_eff.dropna()
rookies_eff.head()
# Out:
#            PLAYER  PICK TEAM  YEAR     G    MP   FG   FGA   FT  FTA  ...  AST  \
# 0  Andrew Wiggins     1  CLE  2014  82.0  36.2  6.1  13.9  4.3  5.7  ...  2.1
# 1   Jabari Parker     2  MIL  2014  25.0  29.5  5.2  10.5  1.8  2.6  ...  1.7
# 3    Aaron Gordon     4  ORL  2014  47.0  17.0  2.0   4.4  0.9  1.3  ...  0.7
# 4      Dante Exum     5  UTA  2014  82.0  22.2  1.8   5.1  0.2  0.4  ...  2.4
# 5    Marcus Smart     6  BOS  2014  67.0  27.0  2.6   7.1  1.2  1.9  ...  3.1
#
#    STL  BLK  TOV   PF   PTS  ADVANCED_WS  ADVANCED_BPM  ADVANCED_VORP   PER
# 0  1.0  0.6  2.2  2.3  16.9         29.1          -1.5            2.8  11.5
# 1  1.2  0.2  1.9  1.7  12.3         13.8          -0.8            2.5  12.6
# 3  0.4  0.5  0.8  1.8   5.2         42.6           0.3           11.3   9.5
# 4  0.5  0.2  1.4  1.8   4.8          5.9          -2.8           -1.2   4.0
# 5  1.5  0.3  1.3  2.6   7.8         33.4          -0.3            7.6   9.3
#
# [5 rows x 22 columns]

# %%
win_share = rookies_eff.groupby('PICK')['ADVANCED_WS'].mean().reset_index()
win_share = win_share.rename(columns={'ADVANCED_WS':'Average Win Share'})
win_share
# Out:
#     PICK  Average Win Share
# 0      1          22.000000
# 1      2          13.355556
# 2      3          21.911111
# 3      4          15.180000
# 4      5          12.070000
# 5      6          14.790909
# 6      7          15.370000
# 7      8           8.000000
# 8      9           9.310000
# 9     10           9.400000
# 10    11          20.890000
# 11    12          14.000000
# 12    13          14.690000
# 13    14          11.611111
# 14    15           5.918182
# 15    16          11.062500
# 16    17           4.680000
# 17    18           3.600000
# 18    19          12.430000
# 19    20           9.966667
# 20    21           7.490909
# 21    22          12.640000
# 22    23           8.812500
# 23    24           5.318182
# 24    25          12.877778
# 25    26           5.250000
# 26    27          14.166667
# 27    28           3.350000
# 28    29           8.866667
# 29    30          14.420000
# 30    31           4.816667
# 31    32           9.309091
# ...

# %%
sns.scatterplot(x='PICK', y='Average Win Share', data=win_share, color = '#242841')
plt.title('Average Win Share by Draft Pick Number')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\ws_pick.jpg')
plt.show()
ws_corr = win_share.corr()
print(ws_corr)
# Out:
#                       PICK  Average Win Share
# PICK               1.00000           -0.76827
# Average Win Share -0.76827            1.00000

# %%
per_pick = rookies_eff.groupby('PICK')['PER'].mean().reset_index()
per_pick = per_pick.rename(columns={'PER':'Player Efficiency Rating'})
per_pick
# Out:
#     PICK  Player Efficiency Rating
# 0      1                 17.300000
# 1      2                 13.200000
# 2      3                 13.466667
# 3      4                 11.970000
# 4      5                  9.590000
# 5      6                 11.790909
# 6      7                  9.240000
# 7      8                 10.610000
# 8      9                 10.900000
# 9     10                  9.270000
# 10    11                  9.710000
# 11    12                 12.288889
# 12    13                 11.360000
# 13    14                  9.655556
# 14    15                  9.581818
# 15    16                 12.325000
# 16    17                  7.600000
# 17    18                  9.800000
# 18    19                  9.850000
# 19    20                 10.166667
# 20    21                 11.236364
# 21    22                 11.880000
# 22    23                 10.262500
# 23    24                  8.718182
# 24    25                 11.111111
# 25    26                  9.550000
# ...

# %%
sns.scatterplot(x='PICK', y='Player Efficiency Rating', data=per_pick, color = '#242841')
plt.title('Average PER by Draft Pick Number')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\per_pick.jpg')
plt.show()
per_corr = per_pick.corr()
print(per_corr)
# Out:
#                               PICK  Player Efficiency Rating
# PICK                      1.000000                 -0.391755
# Player Efficiency Rating -0.391755                  1.000000

# %%
bpm_pick = rookies_eff.groupby('PICK')['ADVANCED_BPM'].mean().reset_index()
bpm_pick = bpm_pick.rename(columns={'ADVANCED_BPM':'Box Plus/Minus'})
bpm_pick
# Out:
#     PICK  Box Plus/Minus
# 0      1        1.444444
# 1      2       -0.655556
# 2      3        0.477778
# 3      4       -0.680000
# 4      5       -1.250000
# 5      6       -0.790909
# 6      7       -1.430000
# 7      8       -1.370000
# 8      9       -2.090000
# 9     10       -2.030000
# 10    11       -0.510000
# 11    12       -0.433333
# 12    13       -1.590000
# 13    14       -1.588889
# 14    15       -3.045455
# 15    16       -1.762500
# 16    17       -3.500000
# 17    18       -2.318182
# 18    19       -1.790000
# 19    20       -1.044444
# 20    21       -1.854545
# 21    22       -1.760000
# 22    23       -1.962500
# 23    24       -2.709091
# 24    25       -1.600000
# 25    26       -2.637500
# 26    27       -0.744444
# 27    28       -3.230000
# 28    29       -2.366667
# 29    30       -0.620000
# 30    31       -3.733333
# 31    32       -2.381818
# 32    33       -1.433333
# 33    34       -3.422222
# 34    35       -2.871429
# 35    36       -2.950000
# ...

# %%
sns.scatterplot(x='PICK', y='Box Plus/Minus', data=bpm_pick, color = '#242841')
plt.title('Average BPM by Draft Pick Number')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\bpm_pick.jpg')
plt.show()
bpm_corr = bpm_pick.corr()
print(bpm_corr)
# Out:
#                     PICK  Box Plus/Minus
# PICK            1.000000       -0.710881
# Box Plus/Minus -0.710881        1.000000

# %%
vorp_pick = rookies_eff.groupby('PICK')['ADVANCED_VORP'].mean().reset_index()
vorp_pick = vorp_pick.rename(columns={'ADVANCED_VORP':'Value Over Replacement Player'})
vorp_pick
# Out:
#     PICK  Value Over Replacement Player
# 0      1                       7.755556
# 1      2                       4.277778
# 2      3                       8.833333
# 3      4                       3.580000
# 4      5                       3.060000
# 5      6                       3.990909
# 6      7                       3.520000
# 7      8                       0.450000
# 8      9                       0.540000
# 9     10                       1.290000
# 10    11                       6.390000
# 11    12                       3.388889
# 12    13                       5.270000
# 13    14                       2.422222
# 14    15                      -0.136364
# 15    16                       2.912500
# 16    17                       0.890000
# 17    18                      -0.181818
# 18    19                       1.950000
# 19    20                       2.211111
# 20    21                       1.172727
# 21    22                       2.200000
# ...

# %%
sns.scatterplot(x='PICK', y='Value Over Replacement Player', data=vorp_pick, color = '#242841')
plt.title('Average VORP by Draft Pick Number')
plt.savefig(r'C:\da12\projects\capstone\capstone_DA12_NBA\vorp_pick.jpg')
plt.show()
vorp_corr = vorp_pick.corr()
print(vorp_corr)
# Out:
#                                    PICK  Value Over Replacement Player
# PICK                           1.000000                      -0.664893
# Value Over Replacement Player -0.664893                       1.000000
